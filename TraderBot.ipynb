# %%
#imports
import importlib
import functionality as fn
import pause
import datetime

# %%
#check market status
importlib.reload(fn)
while True:
    if fn.getMarketStatus() != "open":
        pause.until(datetime.datetime.now().replace(hour=8, minute=31) + datetime.timedelta(days=1))
    else:
        try:
            sp500 = fn.currentSP500()
            accepted = []
            for equity in sp500:
                pause.seconds(1)
                if fn.trend(equity, 30) == "uptrend" and fn.trend(equity, 100) == "downtrend":
                    accepted.append(equity)
            # print("completed equity list")
            for equity in accepted:
                pause.seconds(1)
                change = fn.getPercentChange(equity)
                if fn.getStockBuyingPower() <= fn.getCurrentSymbolPrice(equity) and change != None and change > -2:
                    continue
                else:
                    fn.buyEquity(equity)
            # print("completed buy phase")
            while fn.getMarketStatus() == "open":
                positions = fn.getPositions()
                for i in positions:
                    change = fn.getPercentChange(i[0])
                    print(i[0], change)
                    if change != None and change <= -2:
                        fn.sellEquity(i[0], i[1])
                pause.minutes(15)
            print("completed sell phase, trading day complete")
        except:
            pause.until(datetime.datetime.now().replace(hour=8, minute=31) + datetime.timedelta(days=1))
# Out:
# completed equity list
# bought 1 ADM with order details:
# {'order': {'id': 6891287, 'status': 'ok', 'partner_id': '3a8bbee1-5184-4ffe-8a0c-294fbad1aee9'}}
# bought 1 AMT with order details:
# {'order': {'id': 6891296, 'status': 'ok', 'partner_id': '3a8bbee1-5184-4ffe-8a0c-294fbad1aee9'}}
# bought 1 ACGL with order details:
# {'order': {'id': 6891306, 'status': 'ok', 'partner_id': '3a8bbee1-5184-4ffe-8a0c-294fbad1aee9'}}
# bought 1 AZO with order details:
# {'order': {'id': 6891316, 'status': 'ok', 'partner_id': '3a8bbee1-5184-4ffe-8a0c-294fbad1aee9'}}
# bought 1 CHRW with order details:
# {'order': {'id': 6891327, 'status': 'ok', 'partner_id': '3a8bbee1-5184-4ffe-8a0c-294fbad1aee9'}}
# bought 1 CF with order details:
# {'order': {'id': 6891336, 'status': 'ok', 'partner_id': '3a8bbee1-5184-4ffe-8a0c-294fbad1aee9'}}
# bought 1 CME with order details:
# {'order': {'id': 6891347, 'status': 'ok', 'partner_id': '3a8bbee1-5184-4ffe-8a0c-294fbad1aee9'}}
# bought 1 CTVA with order details:
# {'order': {'id': 6891356, 'status': 'ok', 'partner_id': '3a8bbee1-5184-4ffe-8a0c-294fbad1aee9'}}
# bought 1 CTRA with order details:
# {'order': {'id': 6891367, 'status': 'ok', 'partner_id': '3a8bbee1-5184-4ffe-8a0c-294fbad1aee9'}}
# bought 1 CCI with order details:
# {'order': {'id': 6891378, 'status': 'ok', 'partner_id': '3a8bbee1-5184-4ffe-8a0c-294fbad1aee9'}}
# bought 1 DG with order details:
# {'order': {'id': 6891389, 'status': 'ok', 'partner_id': '3a8bbee1-5184-4ffe-8a0c-294fbad1aee9'}}
# bought 1 DLTR with order details:
# {'order': {'id': 6891398, 'status': 'ok', 'partner_id': '3a8bbee1-5184-4ffe-8a0c-294fbad1aee9'}}
# bought 1 DOW with order details:
# {'order': {'id': 6891409, 'status': 'ok', 'partner_id': '3a8bbee1-5184-4ffe-8a0c-294fbad1aee9'}}
# bought 1 EIX with order details:
# {'order': {'id': 6891418, 'status': 'ok', 'partner_id': '3a8bbee1-5184-4ffe-8a0c-294fbad1aee9'}}
# bought 1 EL with order details:
# {'order': {'id': 6891429, 'status': 'ok', 'partner_id': '3a8bbee1-5184-4ffe-8a0c-294fbad1aee9'}}
# bought 1 EXR with order details:
# {'order': {'id': 6891439, 'status': 'ok', 'partner_id': '3a8bbee1-5184-4ffe-8a0c-294fbad1aee9'}}
# bought 1 XOM with order details:
# {'order': {'id': 6891449, 'status': 'ok', 'partner_id': '3a8bbee1-5184-4ffe-8a0c-294fbad1aee9'}}
# bought 1 GL with order details:
# {'order': {'id': 6891461, 'status': 'ok', 'partner_id': '3a8bbee1-5184-4ffe-8a0c-294fbad1aee9'}}
# bought 1 HES with order details:
# {'order': {'id': 6891470, 'status': 'ok', 'partner_id': '3a8bbee1-5184-4ffe-8a0c-294fbad1aee9'}}
# bought 1 IEX with order details:
# {'order': {'id': 6891480, 'status': 'ok', 'partner_id': '3a8bbee1-5184-4ffe-8a0c-294fbad1aee9'}}
# bought 1 PODD with order details:
# {'order': {'id': 6891490, 'status': 'ok', 'partner_id': '3a8bbee1-5184-4ffe-8a0c-294fbad1aee9'}}
# bought 1 IP with order details:
# {'order': {'id': 6891501, 'status': 'ok', 'partner_id': '3a8bbee1-5184-4ffe-8a0c-294fbad1aee9'}}
# bought 1 KMB with order details:
# {'order': {'id': 6891511, 'status': 'ok', 'partner_id': '3a8bbee1-5184-4ffe-8a0c-294fbad1aee9'}}
# bought 1 KMI with order details:
# {'order': {'id': 6891522, 'status': 'ok', 'partner_id': '3a8bbee1-5184-4ffe-8a0c-294fbad1aee9'}}
# bought 1 KR with order details:
# {'order': {'id': 6891533, 'status': 'ok', 'partner_id': '3a8bbee1-5184-4ffe-8a0c-294fbad1aee9'}}
# bought 1 LHX with order details:
# {'order': {'id': 6891543, 'status': 'ok', 'partner_id': '3a8bbee1-5184-4ffe-8a0c-294fbad1aee9'}}
# bought 1 LYB with order details:
# {'order': {'id': 6891555, 'status': 'ok', 'partner_id': '3a8bbee1-5184-4ffe-8a0c-294fbad1aee9'}}
# bought 1 MPC with order details:
# {'order': {'id': 6891565, 'status': 'ok', 'partner_id': '3a8bbee1-5184-4ffe-8a0c-294fbad1aee9'}}
# bought 1 MRK with order details:
# {'order': {'id': 6891576, 'status': 'ok', 'partner_id': '3a8bbee1-5184-4ffe-8a0c-294fbad1aee9'}}
# bought 1 MET with order details:
# {'order': {'id': 6891586, 'status': 'ok', 'partner_id': '3a8bbee1-5184-4ffe-8a0c-294fbad1aee9'}}
# bought 1 MGM with order details:
# {'order': {'id': 6891597, 'status': 'ok', 'partner_id': '3a8bbee1-5184-4ffe-8a0c-294fbad1aee9'}}
# bought 1 MSI with order details:
# {'order': {'id': 6891609, 'status': 'ok', 'partner_id': '3a8bbee1-5184-4ffe-8a0c-294fbad1aee9'}}
# bought 1 NWL with order details:
# {'order': {'id': 6891620, 'status': 'ok', 'partner_id': '3a8bbee1-5184-4ffe-8a0c-294fbad1aee9'}}
# bought 1 NKE with order details:
# {'order': {'id': 6891631, 'status': 'ok', 'partner_id': '3a8bbee1-5184-4ffe-8a0c-294fbad1aee9'}}
# bought 1 OKE with order details:
# {'order': {'id': 6891640, 'status': 'ok', 'partner_id': '3a8bbee1-5184-4ffe-8a0c-294fbad1aee9'}}
# bought 1 OGN with order details:
# {'order': {'id': 6891648, 'status': 'ok', 'partner_id': '3a8bbee1-5184-4ffe-8a0c-294fbad1aee9'}}
# bought 1 PYPL with order details:
# {'order': {'id': 6891658, 'status': 'ok', 'partner_id': '3a8bbee1-5184-4ffe-8a0c-294fbad1aee9'}}
# bought 1 PEP with order details:
# {'order': {'id': 6891668, 'status': 'ok', 'partner_id': '3a8bbee1-5184-4ffe-8a0c-294fbad1aee9'}}
# bought 1 PXD with order details:
# {'order': {'id': 6891678, 'status': 'ok', 'partner_id': '3a8bbee1-5184-4ffe-8a0c-294fbad1aee9'}}
# bought 1 PG with order details:
# {'order': {'id': 6891688, 'status': 'ok', 'partner_id': '3a8bbee1-5184-4ffe-8a0c-294fbad1aee9'}}
# bought 1 PGR with order details:
# {'order': {'id': 6891699, 'status': 'ok', 'partner_id': '3a8bbee1-5184-4ffe-8a0c-294fbad1aee9'}}
# bought 1 PEG with order details:
# {'order': {'id': 6891711, 'status': 'ok', 'partner_id': '3a8bbee1-5184-4ffe-8a0c-294fbad1aee9'}}
# bought 1 PSA with order details:
# {'order': {'id': 6891723, 'status': 'ok', 'partner_id': '3a8bbee1-5184-4ffe-8a0c-294fbad1aee9'}}
# bought 1 RVTY with order details:
# {'order': {'id': 6891734, 'status': 'ok', 'partner_id': '3a8bbee1-5184-4ffe-8a0c-294fbad1aee9'}}
# bought 1 SBAC with order details:
# {'order': {'id': 6891745, 'status': 'ok', 'partner_id': '3a8bbee1-5184-4ffe-8a0c-294fbad1aee9'}}
# bought 1 SYY with order details:
# {'order': {'id': 6891755, 'status': 'ok', 'partner_id': '3a8bbee1-5184-4ffe-8a0c-294fbad1aee9'}}
# bought 1 TMUS with order details:
# {'order': {'id': 6891765, 'status': 'ok', 'partner_id': '3a8bbee1-5184-4ffe-8a0c-294fbad1aee9'}}
# bought 1 TGT with order details:
# {'order': {'id': 6891777, 'status': 'ok', 'partner_id': '3a8bbee1-5184-4ffe-8a0c-294fbad1aee9'}}
# bought 1 TDY with order details:
# {'order': {'id': 6891793, 'status': 'ok', 'partner_id': '3a8bbee1-5184-4ffe-8a0c-294fbad1aee9'}}
# bought 1 ULTA with order details:
# {'order': {'id': 6891805, 'status': 'ok', 'partner_id': '3a8bbee1-5184-4ffe-8a0c-294fbad1aee9'}}
# bought 1 UPS with order details:
# {'order': {'id': 6891817, 'status': 'ok', 'partner_id': '3a8bbee1-5184-4ffe-8a0c-294fbad1aee9'}}
# bought 1 VLO with order details:
# {'order': {'id': 6891827, 'status': 'ok', 'partner_id': '3a8bbee1-5184-4ffe-8a0c-294fbad1aee9'}}
# bought 1 VZ with order details:
# {'order': {'id': 6891839, 'status': 'ok', 'partner_id': '3a8bbee1-5184-4ffe-8a0c-294fbad1aee9'}}
# bought 1 VFC with order details:
# {'order': {'id': 6891850, 'status': 'ok', 'partner_id': '3a8bbee1-5184-4ffe-8a0c-294fbad1aee9'}}
# bought 1 V with order details:
# {'order': {'id': 6891863, 'status': 'ok', 'partner_id': '3a8bbee1-5184-4ffe-8a0c-294fbad1aee9'}}
# bought 1 WYNN with order details:
# {'order': {'id': 6891874, 'status': 'ok', 'partner_id': '3a8bbee1-5184-4ffe-8a0c-294fbad1aee9'}}
# bought 1 ZTS with order details:
# {'order': {'id': 6891885, 'status': 'ok', 'partner_id': '3a8bbee1-5184-4ffe-8a0c-294fbad1aee9'}}
# completed buy phase
# ACGL 0.33
# ADM 0.07
# AMT 1.49
# AZO 0.6
# CCI 1.84
# CF -2.35
# sold allCF with order details:
# {'order': {'id': 6891896, 'status': 'ok', 'partner_id': '3a8bbee1-5184-4ffe-8a0c-294fbad1aee9'}}
# CHRW -0.76
# CLX -1.54
# CME 1.75
# CNP -1.48
# CTRA 0.97
# CTVA -0.42
# D -1.94
# DG -1.2
# DLTR -0.23
# DOW 0.1
# EIX -1.39
# EL -1.69
# EPAM -0.41
# EVRG -1.45
# EXC -1.74
# EXR 0.14
# FE -1.2
# GD -1.18
# GL -0.71
# HES 0.68
# HLT 0.12
# HOLX -1.4
# IEX -0.34
# IP -1.26
# KMB -1.28
# KMI 0.63
# KO -0.86
# KR 0.11
# LHX -1.95
# LVS -0.85
# LYB 0.07
# MET -0.51
# MGM -0.12
# MPC 1.0
# MRK -0.88
# MSI -0.05
# NI -1.37
# NKE -0.42
# NWL 0.74
# O -0.37
# OGN -0.8
# OKE 0.81
# PEG -1.74
# PEP -1.36
# PG -0.18
# PGR -0.96
# PODD -0.02
# PSA -0.28
# PXD 2.14
# PYPL -0.25
# RHI -0.05
# RVTY 0.93
# SBAC 0.66
# SO -1.83
# SYY -0.48
# T -0.73
# TDY -0.55
# TGT 0.09
# TMUS -0.39
# TXT -0.17
# ULTA -0.68
# UPS 0.34
# V -0.09
# VFC -1.91
# VLO 0.19
# VZ 0.24
# WYNN -1.36
# XOM 1.09
# ZBRA 0.39
# ZTS -0.78
# ACGL 0.27
# ADM 0.13
# AMT 1.51
# AZO 0.6
# CCI 1.58
# CHRW -0.7
# CLX -1.71
# CME 1.95
# CNP -1.44
# CTRA 1.1
# CTVA -0.44
# D -1.87
# DG -1.29
# DLTR -0.22
# DOW 0.05
# EIX -1.53
# EL -1.65
# EPAM -0.13
# EVRG -1.37
# EXC -1.69
# EXR -0.11
# FE -1.28
# GD -1.02
# GL -0.74
# HES 0.82
# HLT 0.49
# HOLX -1.24
# IEX -0.27
# IP -1.25
# KMB -1.28
# KMI 0.66
# KO -0.86
# KR 0.08
# LHX -1.77
# LVS -0.76
# LYB -0.07
# MET -0.42
# MGM 0.08
# MPC 0.89
# MRK -0.99
# MSI 0.02
# NI -1.24
# NKE -0.47
# NWL 0.85
# O -0.42
# OGN -0.8
# OKE 1.06
# PEG -1.84
# PEP -1.37
# PG -0.22
# PGR -0.96
# PODD 0.29
# PSA -0.6
# PXD 2.23
# PYPL -0.38
# RHI 0.05
# RVTY 0.96
# SBAC 0.68
# SO -1.94
# SYY -0.41
# T -0.65
# TDY -0.56
# TGT 0.01
# TMUS -0.39
# TXT -0.12
# ULTA -0.54
# UPS 0.42
# V -0.07
# VFC -1.87
# VLO 0.22
# VZ 0.36
# WYNN -1.07
# XOM 0.94
# ZBRA 0.58
# ZTS -0.76
# ACGL 0.24
# ADM 0.1
# AMT 1.44
# AZO 0.31
# CCI 1.52
# CHRW -0.72
# CLX -1.87
# CME 1.88
# CNP -1.44
# CTRA 1.06
# CTVA -0.51
# D -1.85
# DG -1.4
# DLTR -0.67
# DOW 0.06
# EIX -1.61
# EL -1.72
# EPAM -0.39
# EVRG -1.47
# EXC -1.74
# EXR -0.26
# FE -1.32
# GD -1.0
# GL -0.9
# HES 0.74
# HLT 0.4
# HOLX -1.42
# IEX -0.34
# IP -1.31
# KMB -1.4
# KMI 0.69
# KO -0.94
# KR 0.1
# LHX -1.84
# LVS -0.89
# LYB 0.13
# MET -0.38
# MGM 0.09
# MPC 0.83
# MRK -1.04
# MSI -0.11
# NI -1.32
# NKE -0.45
# NWL 0.74
# O -0.53
# OGN -0.78
# OKE 1.12
# PEG -1.94
# PEP -1.44
# PG -0.39
# PGR -0.97
# PODD -0.01
# PSA -0.85
# PXD 2.32
# PYPL -0.43
# RHI 0.0
# RVTY 0.85
# SBAC 0.52
# SO -1.9
# SYY -0.52
# T -0.6
# TDY -0.7
# TGT -0.11
# TMUS -0.37
# TXT -0.2
# ULTA -0.79
# UPS 0.39
# V -0.15
# VFC -1.83
# VLO 0.04
# VZ 0.36
# WYNN -1.28
# XOM 0.94
# ZBRA 0.32
# ZTS -1.05
# ACGL 0.4
# ADM 0.31
# AMT 1.56
# AZO 0.29
# CCI 1.73
# CHRW -0.75
# CLX -1.76
# CME 1.98
# CNP -1.39
# CTRA 0.85
# CTVA -0.42
# D -1.7
# DG -1.54
# DLTR -0.84
# DOW 0.16
# EIX -1.56
# EL -1.7
# EPAM -0.76
# EVRG -1.57
# EXC -1.73
# EXR -0.16
# FE -1.24
# GD -0.99
# GL -0.86
# HES 0.64
# HLT 0.26
# HOLX -1.29
# IEX -0.32
# IP -1.22
# KMB -1.28
# KMI 0.69
# KO -0.89
# KR 0.15
# LHX -1.71
# LVS -0.98
# LYB 0.0
# MET -0.43
# MGM -0.1
# MPC 0.77
# MRK -1.18
# MSI -0.2
# NI -1.17
# NKE -0.63
# NWL 0.68
# O -0.66
# OGN -0.83
# OKE 1.29
# PEG -1.98
# PEP -1.43
# PG -0.2
# PGR -0.94
# PODD -0.16
# PSA -0.96
# PXD 1.91
# PYPL -0.67
# RHI -0.17
# RVTY 1.21
# SBAC 0.64
# SO -1.77
# SYY -0.58
# T -0.7
# TDY -0.75
# TGT -0.06
# TMUS -0.39
# TXT -0.13
# ULTA -0.75
# UPS 0.33
# V -0.26
# VFC -1.91
# VLO -0.07
# VZ 0.33
# WYNN -1.43
# XOM 0.73
# ZBRA 0.03
# ZTS -1.08
# ACGL 0.48
# ADM 0.35
# AMT 1.63
# AZO 0.3
# CCI 1.65
# CHRW -0.52
# CLX -1.6
# CME 1.95
# CNP -1.37
# CTRA 0.7
# CTVA -0.42
# D -1.6
# DG -1.3
# DLTR -0.66
# DOW 0.4
# EIX -1.55
# EL -1.59
# EPAM -0.47
# EVRG -1.55
# EXC -1.72
# EXR 0.04
# FE -1.27
# GD -0.8
# GL -0.73
# HES 0.71
# HLT 0.46
# HOLX -0.98
# IEX -0.28
# IP -1.03
# KMB -1.1
# KMI 0.93
# KO -0.87
# KR 0.39
# LHX -1.49
# LVS -1.06
# LYB 0.32
# MET -0.3
# MGM -0.03
# MPC 1.01
# MRK -1.29
# MSI -0.12
# NI -1.15
# NKE -0.47
# NWL 1.08
# O -0.61
# OGN -0.88
# OKE 1.34
# PEG -1.97
# PEP -1.35
# PG -0.1
# PGR -0.79
# PODD 0.26
# PSA -0.95
# PXD 2.07
# PYPL -0.43
# RHI 0.1
# RVTY 1.52
# SBAC 0.83
# SO -1.83
# SYY -0.56
# T -0.6
# TDY -0.66
# TGT 0.29
# TMUS -0.19
# TXT 0.0
# ULTA -0.5
# UPS 0.77
# V -0.15
# VFC -1.57
# VLO 0.18
# VZ 0.52
# WYNN -1.29
# XOM 0.86
# ZBRA 0.09
# ZTS -0.96
